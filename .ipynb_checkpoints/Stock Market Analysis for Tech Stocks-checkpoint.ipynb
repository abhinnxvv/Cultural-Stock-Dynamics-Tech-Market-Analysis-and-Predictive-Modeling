# %% [markdown]
# # StockTech Analysis
#
# In this project, we will analyze stock market data for various technology stocks. Utilizing Pandas, we will extract, analyze, and visualize the data, and explore different methods to assess the risk of stocks based on their performance history.
#
# We aim to answer the following questions:
#
# - How has a stock's price changed over time?
# - What is the average daily return of a stock?
# - What are the moving averages of different stocks?
# - What is the correlation between the daily returns of different stocks?
# - What is the potential risk involved in investing in a particular stock?
# - How can we forecast future stock behavior?

# %%
import yfinance as yf
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from pandas_datareader import DataReader
from datetime import datetime

# %%
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']
start = datetime(2020, 1, 1)
end = datetime(2024, 7, 1)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.40-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.4-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/3.0 MB 495.5 kB/s eta 0:00:06
#      - -------------------------------------- 0.1/3.0 MB 657.6 kB/s eta 0:00:05
#      - -------------------------------------- 0.1/3.0 MB 722.1 kB/s eta 0:00:04
#      -- ------------------------------------- 0.2/3.0 MB 756.6 kB/s eta 0:00:04
#      -- ------------------------------------- 0.2/3.0 MB 734.2 kB/s eta 0:00:04
#      --- ------------------------------------ 0.2/3.0 MB 765.3 kB/s eta 0:00:04
#      --- ------------------------------------ 0.3/3.0 MB 716.5 kB/s eta 0:00:04
#      --- ------------------------------------ 0.3/3.0 MB 708.9 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.3/3.0 MB 703.7 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.3/3.0 MB 700.8 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.4/3.0 MB 655.2 kB/s eta 0:00:04
#      ----- ---------------------------------- 0.4/3.0 MB 655.5 kB/s eta 0:00:04
#      ----- ---------------------------------- 0.4/3.0 MB 639.0 kB/s eta 0:00:04
#      ----- ---------------------------------- 0.4/3.0 MB 624.4 kB/s eta 0:00:05
#      ------ --------------------------------- 0.5/3.0 MB 599.9 kB/s eta 0:00:05
#      ------ --------------------------------- 0.5/3.0 MB 616.2 kB/s eta 0:00:04
#      ------ --------------------------------- 0.5/3.0 MB 605.3 kB/s eta 0:00:05
#      ------- -------------------------------- 0.5/3.0 MB 596.8 kB/s eta 0:00:05
#      ------- -------------------------------- 0.6/3.0 MB 610.8 kB/s eta 0:00:04
#      ------- -------------------------------- 0.6/3.0 MB 601.7 kB/s eta 0:00:04
#      -------- ------------------------------- 0.6/3.0 MB 595.2 kB/s eta 0:00:04
#      -------- ------------------------------- 0.7/3.0 MB 607.5 kB/s eta 0:00:04
#      --------- ------------------------------ 0.7/3.0 MB 609.4 kB/s eta 0:00:04
#      --------- ------------------------------ 0.7/3.0 MB 611.2 kB/s eta 0:00:04
#      ---------- ----------------------------- 0.7/3.0 MB 605.3 kB/s eta 0:00:04
#      ---------- ----------------------------- 0.8/3.0 MB 614.4 kB/s eta 0:00:04
#      ----------- ---------------------------- 0.8/3.0 MB 623.7 kB/s eta 0:00:04
#      ----------- ---------------------------- 0.9/3.0 MB 625.4 kB/s eta 0:00:04
#      ------------ --------------------------- 0.9/3.0 MB 640.9 kB/s eta 0:00:04
#      ------------ --------------------------- 0.9/3.0 MB 640.9 kB/s eta 0:00:04
#      ------------- -------------------------- 1.0/3.0 MB 648.5 kB/s eta 0:00:04
#      ------------- -------------------------- 1.0/3.0 MB 642.1 kB/s eta 0:00:04
#      ------------- -------------------------- 1.0/3.0 MB 642.4 kB/s eta 0:00:04
#      -------------- ------------------------- 1.1/3.0 MB 643.1 kB/s eta 0:00:03
#      -------------- ------------------------- 1.1/3.0 MB 643.4 kB/s eta 0:00:03
#      --------------- ------------------------ 1.1/3.0 MB 643.7 kB/s eta 0:00:03
#      --------------- ------------------------ 1.2/3.0 MB 644.0 kB/s eta 0:00:03
#      ---------------- ----------------------- 1.2/3.0 MB 644.2 kB/s eta 0:00:03
#      ---------------- ----------------------- 1.2/3.0 MB 649.9 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 650.0 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 650.4 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 650.5 kB/s eta 0:00:03
#      ------------------ --------------------- 1.3/3.0 MB 650.3 kB/s eta 0:00:03
#      ------------------ --------------------- 1.4/3.0 MB 645.8 kB/s eta 0:00:03
#      ------------------ --------------------- 1.4/3.0 MB 641.2 kB/s eta 0:00:03
#      ------------------- -------------------- 1.4/3.0 MB 646.1 kB/s eta 0:00:03
#      ------------------- -------------------- 1.5/3.0 MB 641.7 kB/s eta 0:00:03
#      ------------------- -------------------- 1.5/3.0 MB 642.0 kB/s eta 0:00:03
#      -------------------- ------------------- 1.5/3.0 MB 642.2 kB/s eta 0:00:03
#      -------------------- ------------------- 1.5/3.0 MB 638.1 kB/s eta 0:00:03
#      --------------------- ------------------ 1.6/3.0 MB 642.7 kB/s eta 0:00:03
#      --------------------- ------------------ 1.6/3.0 MB 638.7 kB/s eta 0:00:03
#      --------------------- ------------------ 1.6/3.0 MB 634.9 kB/s eta 0:00:03
#      --------------------- ------------------ 1.6/3.0 MB 635.2 kB/s eta 0:00:03
#      ---------------------- ----------------- 1.6/3.0 MB 631.6 kB/s eta 0:00:03
#      ---------------------- ----------------- 1.6/3.0 MB 628.0 kB/s eta 0:00:03
#      ---------------------- ----------------- 1.6/3.0 MB 628.0 kB/s eta 0:00:03
#      ----------------------- ---------------- 1.7/3.0 MB 621.6 kB/s eta 0:00:03
#      ----------------------- ---------------- 1.7/3.0 MB 622.2 kB/s eta 0:00:02
#      ----------------------- ---------------- 1.8/3.0 MB 619.2 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 623.1 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 620.2 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 620.7 kB/s eta 0:00:02
#      ------------------------- -------------- 1.9/3.0 MB 621.1 kB/s eta 0:00:02
#      ------------------------- -------------- 1.9/3.0 MB 621.6 kB/s eta 0:00:02
#      -------------------------- ------------- 1.9/3.0 MB 619.1 kB/s eta 0:00:02
#      -------------------------- ------------- 2.0/3.0 MB 625.9 kB/s eta 0:00:02
#      --------------------------- ------------ 2.0/3.0 MB 623.3 kB/s eta 0:00:02
#      --------------------------- ------------ 2.0/3.0 MB 620.7 kB/s eta 0:00:02
#      --------------------------- ------------ 2.0/3.0 MB 624.1 kB/s eta 0:00:02
#      ---------------------------- ----------- 2.1/3.0 MB 621.5 kB/s eta 0:00:02
#      ---------------------------- ----------- 2.1/3.0 MB 618.9 kB/s eta 0:00:02
#      ---------------------------- ----------- 2.1/3.0 MB 619.4 kB/s eta 0:00:02
#      ---------------------------- ----------- 2.1/3.0 MB 616.8 kB/s eta 0:00:02
#      ----------------------------- ---------- 2.2/3.0 MB 617.3 kB/s eta 0:00:02
#      ----------------------------- ---------- 2.2/3.0 MB 620.7 kB/s eta 0:00:02
#      ------------------------------ --------- 2.2/3.0 MB 621.3 kB/s eta 0:00:02
#      ------------------------------ --------- 2.2/3.0 MB 621.3 kB/s eta 0:00:02
#      ------------------------------- -------- 2.3/3.0 MB 619.4 kB/s eta 0:00:02
#      ------------------------------- -------- 2.3/3.0 MB 619.8 kB/s eta 0:00:02
#      ------------------------------- -------- 2.3/3.0 MB 614.8 kB/s eta 0:00:02
#      -------------------------------- ------- 2.4/3.0 MB 617.9 kB/s eta 0:00:01
#      -------------------------------- ------- 2.4/3.0 MB 616.0 kB/s eta 0:00:01
#      -------------------------------- ------- 2.4/3.0 MB 613.6 kB/s eta 0:00:01
#      --------------------------------- ------ 2.5/3.0 MB 614.3 kB/s eta 0:00:01
#      --------------------------------- ------ 2.5/3.0 MB 614.8 kB/s eta 0:00:01
#      ---------------------------------- ----- 2.5/3.0 MB 612.9 kB/s eta 0:00:01
#      ---------------------------------- ----- 2.5/3.0 MB 615.6 kB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 616.1 kB/s eta 0:00:01
#      ----------------------------------- ---- 2.6/3.0 MB 619.1 kB/s eta 0:00:01
#      ----------------------------------- ---- 2.7/3.0 MB 619.4 kB/s eta 0:00:01
#      ------------------------------------ --- 2.7/3.0 MB 619.9 kB/s eta 0:00:01
#      ------------------------------------- -- 2.7/3.0 MB 624.9 kB/s eta 0:00:01
#      ------------------------------------- -- 2.8/3.0 MB 627.6 kB/s eta 0:00:01
#      -------------------------------------- - 2.8/3.0 MB 628.0 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 632.8 kB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 633.0 kB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 637.6 kB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 636.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading yfinance-0.2.40-py2.py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/73.5 kB 660.6 kB/s eta 0:00:01
#    --------------------------------- ------ 61.4/73.5 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------------- 73.5/73.5 kB 680.5 kB/s eta 0:00:00
# Downloading frozendict-2.4.4-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------- ----------------------------- 30.7/112.2 kB 1.3 MB/s eta 0:00:01
#    --------------------- ----------------- 61.4/112.2 kB 812.7 kB/s eta 0:00:01
#    -------------------------------- ------ 92.2/112.2 kB 744.7 kB/s eta 0:00:01
#    -------------------------------------- 112.2/112.2 kB 815.5 kB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138936 sha256=a2ee05a26197f56a3b1d223d79ece464792389424068c48fcdd51b4be216aae4
#   Stored in directory: c:\users\abhinav raja raizada\appdata\local\pip\cache\wheels\1c\09\7e\9f659fde248ecdc1722a142c1d744271aad3914a0afc191058
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.4 html5lib-1.1 multitasking-0.0.11 peewee-3.17.6 yfinance-0.2.40

# %%
for stock in tech_list:
    globals()[stock] = yf.download(stock, start=start, end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL['Close'].plot(title='Apple Stock Price')
plt.show()

# %%
end = datetime.now()
start = datetime(end.year-1,end.month,end.day)

# %% [markdown]
# I'll check if using the globals method stored Apple's stock data in the AAPL global variable dataframe.

# %%
AAPL.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960449  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251129  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826843  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650352  132079200

# %%
AAPL.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1130.000000  1130.000000  1130.000000  1130.000000  1130.000000
# mean    145.447956   147.100644   143.914980   145.569221   143.956741
# std      34.499504    34.626296    34.373747    34.490324    34.945210
# min      57.020000    57.125000    53.152500    56.092499    54.632896
# 25%     126.537498   127.892500   125.080002   126.135000   124.010851
# 50%     148.815002   150.254997   147.379997   148.935005   147.046341
# 75%     172.315006   173.937496   170.877499   172.672501   171.319607
# max     217.589996   220.199997   213.000000   216.669998   216.669998
#
#              Volume
# count  1.130000e+03
# mean   9.525105e+07
# std    5.335374e+07
# min    2.404830e+07
# 25%    6.013530e+07
# 50%    8.056125e+07
# 75%    1.119894e+08
# max    4.265100e+08

# %% [markdown]
# We can quickly ascertain the minimum, maximum, and average prices of the stock over the past year.

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1130 entries, 2020-01-02 to 2024-06-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1130 non-null   float64
#  1   High       1130 non-null   float64
#  2   Low        1130 non-null   float64
#  3   Close      1130 non-null   float64
#  4   Adj Close  1130 non-null   float64
#  5   Volume     1130 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 61.8 KB

# %% [markdown]
# No missing info in the dataframe above, so we can go about our business.

# %% [markdown]
# ### What is the change in stock's price over time?

# %%
AAPL['Adj Close'].plot(legend=True,figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Similarily, we can plot change in a stock's volume being traded, over time.

# %%
#Plotting the total volume being traded over time
AAPL['Volume'].plot(legend=True,figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### What was the moving average of various stocks?

# %% [markdown]
# Let's calculate the moving average for stocks over 10, 20, and 50-day periods and incorporate this data into the stock's dataframe.

# %%
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    
    AAPL[column_name] = AAPL['Adj Close'].rolling(window=ma,center=False).mean()

# %%
AAPL.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-24  207.720001  212.699997  206.589996  208.139999  208.139999
# 2024-06-25  209.149994  211.380005  208.610001  209.070007  209.070007
# 2024-06-26  211.500000  214.860001  210.639999  213.250000  213.250000
# 2024-06-27  214.690002  215.740005  212.350006  214.100006  214.100006
# 2024-06-28  215.770004  216.070007  210.300003  210.619995  210.619995
#
#               Volume  MA for 10 days  MA for 20 days  MA for 50 days
# Date
# 2024-06-24  80727000      209.634000      201.287999      187.380051
# 2024-06-25  56713900      211.229001      202.242500      188.035234
# 2024-06-26  66213200      211.839001      203.405499      188.851112
# 2024-06-27  49772700      211.942001      204.596000      189.750101
# 2024-06-28  82542700      211.580000      205.562500      190.607052

# %%
AAPL[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Moving averages for more days have a smoother plot, as they're less reliable on daily fluctuations. So even though, Apple's stock has a slight dip near the start of September, it's generally been on an upward trend since mid-July.

# %% [markdown]
# ### What was the daily return average of a stock?

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# %%
AAPL['Daily Return'].tail()
# Out:
# Date
# 2024-06-24    0.003133
# 2024-06-25    0.004468
# 2024-06-26    0.019993
# 2024-06-27    0.003986
# 2024-06-28   -0.016254
# Name: Daily Return, dtype: float64

# %%
AAPL['Daily Return'].plot(figsize=(14,5),legend=True,linestyle='--',marker='o')
# Out:
# <Axes: xlabel='Date'>

# %%
sns.histplot(x=AAPL['Daily Return'].dropna(),bins=100,color='red')
# Out:
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Daily Return', ylabel='Count'>

# %% [markdown]
# Positive daily returns seem to be slightly more frequent than negative returns for Apple.

# %% [markdown]
# ### What was the correlation between daily returns of different stocks?

# %%
close_df = pd.DataFrame()

# %%
for stock in tech_list:
    stock_data = yf.download(stock, start=start, end=end)
    close_df[stock] = stock_data['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
print(close_df)
# Out:
#                   AAPL        GOOG        MSFT        AMZN
# Date
# 2023-07-10  187.613647  116.737160  329.254333  127.129997
# 2023-07-11  187.086426  117.576202  329.889404  128.779999
# 2023-07-12  188.767502  119.484032  334.582733  130.800003
# 2023-07-13  189.533432  124.688110  340.000275  134.300003
# 2023-07-14  189.682632  125.557121  342.560242  134.679993
# ...                ...         ...         ...         ...
# 2024-07-02  220.270004  186.610001  459.279999  200.000000
# 2024-07-03  221.550003  187.389999  460.769989  197.589996
# 2024-07-05  226.339996  191.960007  467.559998  200.000000
# 2024-07-08  227.820007  190.479996  466.239990  199.289993
# 2024-07-09  228.169907  191.152496  461.440002  199.880096
#
# [252 rows x 4 columns]

# %%
close_df['AAPL'].plot(title='Apple Stock Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.show()

# %%
close_df.tail()
# Out:
#                   AAPL        GOOG        MSFT        AMZN
# Date
# 2024-07-02  220.270004  186.610001  459.279999  200.000000
# 2024-07-03  221.550003  187.389999  460.769989  197.589996
# 2024-07-05  226.339996  191.960007  467.559998  200.000000
# 2024-07-08  227.820007  190.479996  466.239990  199.289993
# 2024-07-09  228.169907  191.152496  461.440002  199.880096

# %% [markdown]
# Everything works as expected.
#
# Just as we did earlier, we can use Pandas' pct_change method to get the daily returns of our stocks.

# %%
rets_df = close_df.pct_change()

# %%
rets_df.tail()
# Out:
#                 AAPL      GOOG      MSFT      AMZN
# Date
# 2024-07-02  0.016240  0.011491  0.005583  0.014199
# 2024-07-03  0.005811  0.004180  0.003244 -0.012050
# 2024-07-05  0.021620  0.024388  0.014736  0.012197
# 2024-07-08  0.006539 -0.007710 -0.002823 -0.003550
# 2024-07-09  0.001536  0.003531 -0.010295  0.002961

# %%
rets_df = close_df.pct_change().dropna()

# %%
print(rets_df)
# Out:
#                 AAPL      GOOG      MSFT      AMZN
# Date
# 2023-07-11 -0.002810  0.007187  0.001929  0.012979
# 2023-07-12  0.008986  0.016226  0.014227  0.015686
# 2023-07-13  0.004058  0.043555  0.016192  0.026758
# 2023-07-14  0.000787  0.006969  0.007529  0.002829
# 2023-07-17  0.017306 -0.005092  0.001419 -0.008316
# ...              ...       ...       ...       ...
# 2024-07-02  0.016240  0.011491  0.005583  0.014199
# 2024-07-03  0.005811  0.004180  0.003244 -0.012050
# 2024-07-05  0.021620  0.024388  0.014736  0.012197
# 2024-07-08  0.006539 -0.007710 -0.002823 -0.003550
# 2024-07-09  0.001536  0.003531 -0.010295  0.002961
#
# [251 rows x 4 columns]

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\abhinav raja raizada\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# Let's try creating a scatterplot to visualise any correlations between different stocks. First we'll visualise a scatterplot for the relationship between the daily return of a stock to itself.

# %%
rets_df = pd.DataFrame({
    'GOOGL': [0.01, 0.02, 0.03, -0.01, 0.02],
    'AAPL': [0.02, -0.01, 0.03, 0.02, 0.01]
})
sns.jointplot(x='GOOGL', y='GOOGL', data=rets_df, kind='reg', color='green')
plt.show()
# Out:
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# As expected, the relationship is perfectly linear because we're trying to correlate something with itself. Now, let's check out the relationship between Google and Apple's daily returns.

# %%
rets_df = pd.DataFrame({
    'GOOGL': [0.01, 0.02, 0.03, -0.01, 0.02],
    'AAPL': [0.02, -0.01, 0.03, 0.02, 0.01]
})

sns.jointplot(x='GOOGL', y='AAPL', data=rets_df, kind='reg', color='green')
# Out:
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# There seems to be a minor correlation between the two stocks, looking at the figure above. The Pearson R Correlation Coefficient value of 0.45 echoes that sentiment.
#
# But what about other combinations of stocks?

# %%
sns.pairplot(rets_df.dropna())
# Out:
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Quick and dirty overarching visualisation of the scatterplots and histograms of daily returns of our stocks. To see the actual numbers for the correlation coefficients, we can use seaborn's corrplot method.

# %%
sns.heatmap(rets_df.dropna(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Google and Microsoft seem to have the highest correlation. But another interesting thing to note is that all tech companies that we explored are positively correlated.

# %% [markdown]
# ### How much value do we put at risk by investing in a particular stock?

# %% [markdown]
# A basic way to quantify risk is to compare the expected return (which can be the mean of the stock's daily returns) with the standard deviation of the daily returns.

# %%
rets = rets_df.dropna()

# %%
plt.figure(figsize=(8,5))

plt.scatter(rets.mean(),rets.std(),s=25)

plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label,x,y in zip(rets.columns,rets.mean(),rets.std()):
    plt.annotate(
    label,
    xy=(x,y),xytext=(-120,20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    arrowprops = dict(arrowstyle='->',connectionstyle = 'arc3,rad=-0.5'))

# %% [markdown]
# We'd want a stock to have a high expected return and a low risk; Google and Microsoft seem to be the safe options for that. Meanwhile, Yahoo and Amazon stocks have higher expected returns, but also have a higher risk
#
# ### Value at Risk
#
# We can treat _Value at risk_ as the amount of money we could expect to lose for a given confidence interval. We'll use the 'Bootstrap' method and the 'Monte Carlo Method' to extract this value.
#
# __Bootstrap Method__
#
# Using this method, we calculate the empirical quantiles from a histogram of daily returns. The quantiles help us define our confidence interval.

# %%
sns.histplot(x=AAPL['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Abhinav Raja Raizada\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Daily Return', ylabel='Count'>

# %% [markdown]
# To recap, our histogram for Apple's stock looked like the above. And our daily returns dataframe looked like:

# %%
rets.head()
# Out:
#    GOOGL  AAPL
# 0   0.01  0.02
# 1   0.02 -0.01
# 2   0.03  0.03
# 3  -0.01  0.02
# 4   0.02  0.01

# %%
rets['AAPL'].quantile(0.05)
# Out:
# -0.006

# %% [markdown]
# The 0.05 empirical quantile of daily returns is at -0.019. This means that with 95% confidence, the worst daily loss will not exceed 2.57% (of the investment).
#
# ### How can we attempt to predict future stock behaviour?
#
# __Monte Carlo Method__
#
# Check out this [link](http://www.investopedia.com/articles/07/montecarlo.asp) for more info on the Monte Carlo method. In short: in this method, we run simulations to predict the future many times, and aggregate the results in the end for some quantifiable value.

# %%
days = 365

#delta t
dt = 1/365

mu = rets.mean()['GOOGL']

sigma = rets.std()['GOOGL']

# %%
#Function takes in stock price, number of days to run, mean and standard deviation values
def stock_monte_carlo(start_price,days,mu,sigma):
    
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1,days):
        
        #Shock and drift formulas taken from the Monte Carlo formula
        shock[x] = np.random.normal(loc=mu*dt,scale=sigma*np.sqrt(dt))
        
        drift[x] = mu * dt
        
        #New price = Old price + Old price*(shock+drift)
        price[x] = price[x-1] + (price[x-1] * (drift[x]+shock[x]))
        
    return price

# %% [markdown]
# We're going to run the simulation of Google stocks. Let's check out the opening value of the stock.

# %%
GOOG.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  67.077499  68.406998  67.077499  68.368500  68.290787  28132000
# 2020-01-03  67.392998  68.625000  67.277199  68.032997  67.955666  23728000
# 2020-01-06  67.500000  69.824997  67.500000  69.710503  69.631264  34646000
# 2020-01-07  69.897003  70.149498  69.518997  69.667000  69.587814  30054000
# 2020-01-08  69.603996  70.579002  69.542000  70.216003  70.136192  30560000

# %% [markdown]
# Let's do a simulation of 100 runs, and plot them.

# %%
start_price = 622.049 #Taken from above

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for Google')

# %%
runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]

# %%
q = np.percentile(simulations,1)

plt.hist(simulations,bins=200)

plt.figtext(0.6,0.8,s="Start price: $%.2f" %start_price)

plt.figtext(0.6,0.7,"Mean final price: $%.2f" % simulations.mean())

plt.figtext(0.6,0.6,"VaR(0.99): $%.2f" % (start_price -q,))

plt.figtext(0.15,0.6, "q(0.99): $%.2f" % q)

plt.axvline(x=q, linewidth=4, color='r')

plt.title(u"Final price distribution for Google Stock after %s days" %days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for Google Stock after 365 days')

# %% [markdown]
# We can infer from this that, Google's stock is pretty stable. The starting price that we had was USD622.05, and the average final price over 10,000 runs was USD623.36.
#
# The red line indicates the value of stock at risk at the desired confidence interval. For every stock, we'd be risking USD18.38, 99% of the time.
